# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../dataset/Algerian_forest_fires_dataset_CLEANED.csv")

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
## drop month, day and year
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         100
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## Encoding
df['Classes'] = np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    105
# Name: count, dtype: int64

# %%
##Independent and Dependent features
X = df.drop('FWI',axis=1)
y = df['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y.head()
# Out:
# 0    0.5
# 1    0.4
# 2    0.1
# 3    0.0
# 4    0.5
# Name: FWI, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((181, 11), (61, 11))

# %%
## Feature Selection based on correlation
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.650346 -0.302105 -0.329711  0.703237  0.494261
# RH             -0.650346  1.000000  0.266525  0.234932 -0.634330 -0.413931
# Ws             -0.302105  0.266525  1.000000  0.219681 -0.171843  0.000277
# Rain           -0.329711  0.234932  0.219681  1.000000 -0.546501 -0.286855
# FFMC            0.703237 -0.634330 -0.171843 -0.546501  1.000000  0.621240
# DMC             0.494261 -0.413931  0.000277 -0.286855  0.621240  1.000000
# DC              0.377424 -0.246125  0.105115 -0.300276  0.537884  0.876734
# ISI             0.617606 -0.693939  0.005360 -0.346706  0.751558  0.693404
# BUI             0.466352 -0.364136  0.038701 -0.297934  0.610780  0.983698
# Classes         0.525551 -0.435094 -0.059470 -0.386323  0.780805  0.613507
# Region          0.249598 -0.364007 -0.235477 -0.065132  0.222702  0.196778
#
#                    DC       ISI       BUI   Classes    Region
# Temperature  0.377424  0.617606  0.466352  0.525551  0.249598
# RH          -0.246125 -0.693939 -0.364136 -0.435094 -0.364007
# Ws           0.105115  0.005360  0.038701 -0.059470 -0.235477
# Rain        -0.300276 -0.346706 -0.297934 -0.386323 -0.065132
# FFMC         0.537884  0.751558  0.610780  0.780805  0.222702
# DMC          0.876734  0.693404  0.983698  0.613507  0.196778
# DC           1.000000  0.548992  0.946992  0.546427 -0.081403
# ISI          0.548992  1.000000  0.659589  0.749722  0.266275
# BUI          0.946992  0.659589  1.000000  0.609708  0.096607
# Classes      0.546427  0.749722  0.609708  1.000000  0.161852
# Region      -0.081403  0.266275  0.096607  0.161852  1.000000

# %%
## Check for multicollinearity
plt.figure(figsize=(12,10))
corr = X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold -- Domain expertise
corr_features = correlation(X_train,0.85)

# %%
## drop features when correlation is more than 0.85
X_train.drop(corr_features, axis = 1,inplace=True)
X_test.drop(corr_features, axis = 1,inplace=True)

# %%
X_train.shape,X_test.shape
# Out:
# ((181, 9), (61, 9))

# %% [markdown]
# ## Feature Scaling or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.82836812,  0.75305576,  1.27406033, ..., -0.60658617,
#         -1.07459849, -0.98356052],
#        [-0.02800533, -0.52331623, -0.52192814, ...,  0.08124507,
#          0.93058013,  1.01671425],
#        [-0.82836812, -1.46380085, -2.67711431, ..., -0.46427625,
#          0.93058013,  1.01671425],
#        ...,
#        [-1.89551851,  0.88741071,  0.55566494, ..., -1.05723422,
#         -1.07459849, -0.98356052],
#        [ 1.03914506, -0.45613875,  0.19646725, ...,  0.84023126,
#          0.93058013,  1.01671425],
#        [-0.56158052,  0.95458818,  1.99245572, ..., -0.84376935,
#         -1.07459849, -0.98356052]], shape=(181, 9))

# %% [markdown]
# ## Box plots to understand Effect of Standard Scaler

# %%
plt.subplots(figsize = (15,5))
plt.subplot(1,2,1)
sns.boxplot(data = X_train)
plt.title('X_train Before Scaling')
plt.subplot(1,2,2)
sns.boxplot(data = X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg = LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean absolute error: ",mae)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error:  0.5838063599546971
# R2 Score:  0.983523052949508

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",mae)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean Absolute Error:  1.1459979969391694
# R2 Score:  0.9497712193501187

# %% [markdown]
# ## Cross Validation Lasso

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv = 5)
lassocv.fit(X_train_scaled,y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv.alpha_
# Out:
# np.float64(0.06949475329820431)

# %%
lassocv.alphas_
# Out:
# array([6.94947533, 6.48110395, 6.04429924, 5.6369337 , 5.25702323,
#        4.90271746, 4.57229071, 4.26413362, 3.97674529, 3.70872596,
#        3.45877025, 3.22566071, 3.00826197, 2.80551518, 2.61643285,
#        2.44009403, 2.27563986, 2.12226935, 1.9792355 , 1.84584165,
#        1.7214381 , 1.60541894, 1.49721907, 1.39631152, 1.3022048 ,
#        1.21444055, 1.13259132, 1.05625846, 0.98507017, 0.91867974,
#        0.8567638 , 0.79902079, 0.74516946, 0.69494753, 0.6481104 ,
#        0.60442992, 0.56369337, 0.52570232, 0.49027175, 0.45722907,
#        0.42641336, 0.39767453, 0.3708726 , 0.34587702, 0.32256607,
#        0.3008262 , 0.28055152, 0.26164329, 0.2440094 , 0.22756399,
#        0.21222694, 0.19792355, 0.18458417, 0.17214381, 0.16054189,
#        0.14972191, 0.13963115, 0.13022048, 0.12144406, 0.11325913,
#        0.10562585, 0.09850702, 0.09186797, 0.08567638, 0.07990208,
#        0.07451695, 0.06949475, 0.06481104, 0.06044299, 0.05636934,
#        0.05257023, 0.04902717, 0.04572291, 0.04264134, 0.03976745,
#        0.03708726, 0.0345877 , 0.03225661, 0.03008262, 0.02805515,
#        0.02616433, 0.02440094, 0.0227564 , 0.02122269, 0.01979236,
#        0.01845842, 0.01721438, 0.01605419, 0.01497219, 0.01396312,
#        0.01302205, 0.01214441, 0.01132591, 0.01056258, 0.0098507 ,
#        0.0091868 , 0.00856764, 0.00799021, 0.00745169, 0.00694948])

# %%
lassocv.mse_path_
# Out:
# array([[54.96561328, 59.15785653, 38.72729712, 78.24916791, 53.00661707],
#        [48.33127341, 52.98238939, 33.40705056, 76.17370919, 47.37592787],
#        [42.489492  , 46.9476325 , 28.61641869, 69.11179183, 42.46600092],
#        [37.38816074, 41.6222327 , 24.54198449, 62.88571919, 38.18380814],
#        [32.93231013, 36.95463498, 21.08421335, 57.39228141, 33.53847098],
#        [29.03908563, 32.86149181, 18.15701813, 52.54133041, 29.14966015],
#        [25.63631212, 29.27011099, 15.68586523, 48.25410422, 25.34331445],
#        [22.66140204, 26.11749884, 13.60632992, 43.16468118, 22.0425561 ],
#        [20.05957707, 23.34834079, 11.86266757, 37.9874641 , 19.18168383],
#        [17.78321296, 20.91452315, 10.40680285, 33.46741145, 16.70233718],
#        [15.79082322, 18.77407566,  9.19714128, 29.52048402, 14.5542223 ],
#        [14.0461701 , 16.89025254,  8.19780164, 26.07233474, 12.69363691],
#        [12.51796119, 15.23137028,  7.37783328, 23.06047803, 11.08260866],
#        [11.17864417, 13.76938633,  6.71043366, 20.42825298,  9.68780601],
#        [10.0043003 , 12.47994657,  6.17286425, 18.12706497,  8.48129676],
#        [ 8.97408019, 11.34178204,  5.745228  , 16.11459225,  7.43778832],
#        [ 8.06980707, 10.33631288,  5.41051576, 14.35397185,  6.53565474],
#        [ 7.27563158,  9.4473035 ,  5.15411532, 12.8130922 ,  5.75611405],
#        [ 6.57765905,  8.66047692,  4.96348679, 11.46339338,  5.0828554 ],
#        [ 5.9639872 ,  7.96360923,  4.82764974, 10.28174426,  4.50171559],
#        [ 5.42401339,  7.34574491,  4.73787108,  9.24623544,  4.00039772],
#        [ 4.94855836,  6.79738642,  4.68604922,  8.33835432,  3.56803944],
#        [ 4.52961026,  6.31022001,  4.6654696 ,  7.54196578,  3.19577876],
#        [ 4.16017441,  5.87696496,  4.67041218,  6.8430034 ,  2.87535393],
#        [ 3.83414257,  5.4912424 ,  4.69601322,  6.2292022 ,  2.59978702],
#        [ 3.5461791 ,  5.14746097,  4.73814623,  5.6898661 ,  2.3630248 ],
#        [ 3.29157705,  4.84068218,  4.7929806 ,  5.2156655 ,  2.15981668],
#        [ 3.06635811,  4.56668174,  4.85826   ,  4.79812139,  1.98560918],
#        [ 2.86690726,  4.32163792,  4.85826   ,  4.43085438,  1.83645426],
#        [ 2.6901084 ,  4.10223271,  5.00953273,  4.1072782 ,  1.70884959],
#        [ 2.53323529,  3.9055498 ,  5.00953273,  3.82197985,  1.6000058 ],
#        [ 2.39390169,  3.72902423,  5.176363  ,  3.5702343 ,  1.50725491],
#        [ 2.27001806,  3.57039852,  5.176363  ,  3.34791441,  1.42837118],
#        [ 2.15975389,  3.42768443,  5.34809926,  3.1514142 ,  1.36142801],
#        [ 2.06150483,  3.29912957,  5.34809926,  2.97758211,  1.30475785],
#        [ 1.97386408,  3.1831882 ,  5.51718609,  2.82412178,  1.25691793],
#        [ 1.89558178,  3.07851028,  5.51718609,  2.69763919,  1.21666045],
#        [ 1.82560877,  2.9838638 ,  5.67991087,  2.58526091,  1.18290672],
#        [ 1.76297452,  2.89819401,  5.67991087,  2.48578311,  1.15473055],
#        [ 1.70684269,  2.82055766,  5.83297475,  2.3976446 ,  1.13132173],
#        [ 1.65647791,  2.750119  ,  5.83297475,  2.31947743,  1.11198354],
#        [ 1.61285395,  2.68613696,  5.97482522,  2.25008449,  1.096117  ],
#        [ 1.5749121 ,  2.62795374,  5.97482522,  2.18831335,  1.08320569],
#        [ 1.5407818 ,  2.62795374,  6.10479839,  2.1334621 ,  1.07302714],
#        [ 1.51001843,  2.52670846,  6.10479839,  2.08461075,  1.06557105],
#        [ 1.48253488,  2.52670846,  6.22239573,  2.04105852,  1.05130415],
#        [ 1.44361696,  2.4331532 ,  6.22239573,  2.00218692,  1.04027734],
#        [ 1.40765652,  2.4331532 ,  6.32678199,  1.96725881,  1.03604109],
#        [ 1.37528667,  2.32685961,  6.32678199,  1.93620419,  1.03446397],
#        [ 1.34636212,  2.32685961,  6.39379062,  1.8799754 ,  1.03464149],
#        [ 1.32037727,  2.24148062,  6.39379062,  1.82969686,  1.03633741],
#        [ 1.29699956,  2.24148062,  6.45877505,  1.78491222,  1.03922212],
#        [ 1.27594187,  2.17249458,  6.45877505,  1.74496407,  1.04303368],
#        [ 1.25695089,  2.17249458,  6.52522676,  1.70870496,  1.04756285],
#        [ 1.23980299,  2.11651269,  6.52522676,  1.67518241,  1.05263433],
#        [ 1.22430059,  2.11651269,  6.63768116,  1.64521276,  1.05810119],
#        [ 1.21026901,  2.07086259,  6.63768116,  1.62233629,  1.06384074],
#        [ 1.19755363,  2.07086259,  6.74840209,  1.60486873,  1.06975112],
#        [ 1.19755363,  2.03067103,  6.74840209,  1.59091386,  1.07574816],
#        [ 1.17538555,  1.9885686 ,  6.85440436,  1.56284719,  1.06219784],
#        [ 1.13567633,  1.95061092,  6.85440436,  1.53230713,  1.04618612],
#        [ 1.09915622,  1.91616619,  6.9532463 ,  1.50555672,  1.03252043],
#        [ 1.06619747,  1.88535508,  6.9532463 ,  1.48245897,  1.02101899],
#        [ 1.03685036,  1.85753043,  7.04699807,  1.46238235,  1.011299  ],
#        [ 1.01047648,  1.83211861,  7.04699807,  1.44493318,  1.00310634],
#        [ 0.98674885,  1.8093718 ,  7.1401132 ,  1.42976843,  0.99622461],
#        [ 0.96677314,  1.78875536,  7.1401132 ,  1.41658975,  0.99046661],
#        [ 0.95375418,  1.78875536,  7.23802204,  1.40513773,  0.99046661],
#        [ 0.94236476,  1.7545972 ,  7.23802204,  1.39511669,  0.98140736],
#        [ 0.93249956,  1.74234128,  7.32488819,  1.38647606,  0.97842413],
#        [ 0.9237785 ,  1.73146221,  7.32488819,  1.37897134,  0.97573913],
#        [ 0.9163957 ,  1.72168459,  7.3974343 ,  1.37245176,  0.97357541],
#        [ 0.90931889,  1.71270557,  7.3974343 ,  1.36678861,  0.97184298],
#        [ 0.90301965,  1.70479407,  7.44583839,  1.36186984,  0.96956409],
#        [ 0.89777981,  1.69701896,  7.44583839,  1.35759805,  0.97008849],
#        [ 0.89509483,  1.69001876,  7.4928094 ,  1.35387958,  0.97185251],
#        [ 0.89287963,  1.68352155,  7.4928094 ,  1.35065531,  0.97388606],
#        [ 0.89128769,  1.67778586,  7.53189928,  1.34786136,  0.97601605],
#        [ 0.88987186,  1.67258297,  7.53189928,  1.34543587,  0.9781    ],
#        [ 0.8889447 ,  1.66769754,  7.56727732,  1.34398558,  0.98032504],
#        [ 0.88792044,  1.66340597,  7.56727732,  1.34340731,  0.98255535],
#        [ 0.88792839,  1.65933697,  7.60045118,  1.34310923,  0.98466774],
#        [ 0.88823672,  1.6559359 ,  7.61279151,  1.34299812,  0.9868519 ],
#        [ 0.88854367,  1.65360886,  7.61279151,  1.3430376 ,  0.98889418],
#        [ 0.88913191,  1.65128369,  7.64132613,  1.34124247,  0.99097823],
#        [ 0.88963756,  1.64935258,  7.64132613,  1.33946782,  0.99282614],
#        [ 0.89035291,  1.64812866,  7.6652677 ,  1.33791245,  0.99510256],
#        [ 0.89115289,  1.64714091,  7.67425987,  1.33654329,  0.99697987],
#        [ 0.89197738,  1.64610877,  7.67425987,  1.33540812,  0.99891956],
#        [ 0.89265292,  1.64517947,  7.6952505 ,  1.33434535,  1.00072198],
#        [ 0.89344251,  1.64455663,  7.6952505 ,  1.33339933,  1.00250676],
#        [ 0.89428371,  1.64405081,  7.71246661,  1.33256373,  1.00423746],
#        [ 0.8951173 ,  1.64342904,  7.71246661,  1.33188718,  1.00588657],
#        [ 0.89579601,  1.64303631,  7.72740161,  1.33123928,  1.00745346],
#        [ 0.89652819,  1.642743  ,  7.72740161,  1.33065421,  1.00887623],
#        [ 0.8972998 ,  1.64249846,  7.74057484,  1.33013501,  1.01025318],
#        [ 0.89805579,  1.64212457,  7.74528851,  1.32973085,  1.01158776],
#        [ 0.89878326,  1.6420842 ,  7.74528851,  1.32933174,  1.01285334],
#        [ 0.89936765,  1.64183556,  7.75728429,  1.32896301,  1.01404812],
#        [ 0.89996672,  1.64168702,  7.76108786,  1.32863306,  1.01513375]])

# %%
from sklearn.metrics import accuracy_score
y_pred = lassocv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)

# %% [markdown]
# ## Ridge Regression model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge = Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean Absolute Error: ",mae)
print("R2 Score: ", score)
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error:  0.612551563810103
# R2 Score:  0.9826983552292979

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv = 5)
ridgecv.fit(X_train_scaled,y_train)
y_pred = ridgecv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",mae)
print("R2 Score: ",score)
# Out:
# Mean Absolute Error:  0.8566908888843284
# R2 Score:  0.9729928114396738

# %%
ridgecv.alpha_
# Out:
# np.float64(10.0)

# %%
ridgecv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': False}

# %% [markdown]
# ## Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elasticnet = ElasticNet()
elasticnet.fit(X_train_scaled,y_train)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",mae)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean Absolute Error:  0.612551563810103
# R2 Score:  0.9826983552292979

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elasticnetcv = ElasticNetCV()
elasticnetcv.fit(X_train_scaled,y_train)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",mae)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean Absolute Error:  0.8566908888843284
# R2 Score:  0.9729928114396738
